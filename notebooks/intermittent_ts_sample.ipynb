# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from functools import partial
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df_calendar = pd.read_csv("../data/calendar.csv", parse_dates=["date"])
df_wide_train_val = pd.read_csv("../data/sales_train_validation.csv")
df_prices = pd.read_csv("../data/sell_prices.csv")

# %%
def fourier_modes(df: pd.DataFrame, t_col: str="day_of_year", T: float=365.25 , k: int=1, prefix: str="year") -> pd.DataFrame:
    for order in range(1, k+1):
        df[f"{prefix}_sin_{order}"] = np.sin(2 * np.pi * (order * df[t_col] / T))
        df[f"{prefix}_cos_{order}"] = np.cos(2 * np.pi * (order * df[t_col] / T))
    return df

# %%
df_calendar.insert(2, "day_of_year", df_calendar['date'].dt.dayofyear)
df_calendar.insert(4, "week_of_year", df_calendar['date'].dt.isocalendar().week)
df_calendar['event_name'] = df_calendar['event_name_1'].apply(lambda s: s if isinstance(s, str) else "No Event")
df_calendar['event'] = df_calendar['event_name'].apply(lambda el: 1 if el != "No Event" else 0)
df_calendar = df_calendar[['date', 'wm_yr_wk', 'day_of_year', 'weekday', 'week_of_year', 'month', 'year', 'd', 'event_name', 'event', "snap_CA",	"snap_TX",	"snap_WI"]]

df_calendar = fourier_modes(df_calendar)
# create a mapping from d_i days to date
day2date = df_calendar.set_index('d')['date'].to_dict()
date2day = {date: day for day, date in day2date.items()}
df_calendar
# Out:
#            date  wm_yr_wk  day_of_year    weekday  week_of_year  month  year  \
# 0    2011-01-29     11101           29   Saturday             4      1  2011
# 1    2011-01-30     11101           30     Sunday             4      1  2011
# 2    2011-01-31     11101           31     Monday             5      1  2011
# 3    2011-02-01     11101           32    Tuesday             5      2  2011
# 4    2011-02-02     11101           33  Wednesday             5      2  2011
# ...         ...       ...          ...        ...           ...    ...   ...
# 1964 2016-06-15     11620          167  Wednesday            24      6  2016
# 1965 2016-06-16     11620          168   Thursday            24      6  2016
# 1966 2016-06-17     11620          169     Friday            24      6  2016
# 1967 2016-06-18     11621          170   Saturday            24      6  2016
# 1968 2016-06-19     11621          171     Sunday            24      6  2016
#
#            d    event_name  event  snap_CA  snap_TX  snap_WI  year_sin_1  \
# 0        d_1      No Event      0        0        0        0    0.478434
# 1        d_2      No Event      0        0        0        0    0.493468
# 2        d_3      No Event      0        0        0        0    0.508356
# 3        d_4      No Event      0        1        1        0    0.523094
# 4        d_5      No Event      0        1        0        1    0.537677
# ...      ...           ...    ...      ...      ...      ...         ...
# 1964  d_1965      No Event      0        0        1        1    0.265563
# 1965  d_1966      No Event      0        0        0        0    0.248940
# 1966  d_1967      No Event      0        0        0        0    0.232243
# 1967  d_1968      No Event      0        0        0        0    0.215477
# 1968  d_1969  NBAFinalsEnd      1        0        0        0    0.198648
#
#       year_cos_1
# 0       0.878124
# 1       0.869764
# 2       0.861147
# 3       0.852275
# 4       0.843151
# ...          ...
# 1964   -0.964094
# 1965   -0.968519
# 1966   -0.972658
# 1967   -0.976509
# 1968   -0.980071
#
# [1969 rows x 15 columns]

# %%
fig, ax = plt.subplots(figsize=(6, 4), layout="tight")
df_calendar.set_index("date")[["year_sin_1", "year_cos_1"]].plot(ax=ax)
fig.autofmt_xdate()
ax.legend(loc="upper right")
ax.set_title("yealry seasonality")
plt.show()

# %%
start_date = pd.Timestamp("2012-01-01")
start_day = date2day[start_date]
end_date = pd.Timestamp("2016-01-31")
end_day = date2day[end_date]

# %%
date_cols = (df_wide_train_val.columns[(df_wide_train_val.columns == start_day).argmax(): (df_wide_train_val.columns == end_day).argmax()+1 ]).tolist()
cat_cols = df_wide_train_val.select_dtypes("O").columns.tolist()
cols = cat_cols + date_cols

# %%
df_wide_train_val.shape
# Out:
# (30490, 1919)

# %%
dept_id = "FOODS_3"
store_id = "CA_1"

# %%
df_wide_train_val = df_wide_train_val.query("dept_id == @dept_id and store_id == @store_id")[cols]
df_wide_train_val.head()
# Out:
#                                id      item_id  dept_id cat_id store_id  \
# 2226  FOODS_3_001_CA_1_validation  FOODS_3_001  FOODS_3  FOODS     CA_1
# 2227  FOODS_3_002_CA_1_validation  FOODS_3_002  FOODS_3  FOODS     CA_1
# 2228  FOODS_3_003_CA_1_validation  FOODS_3_003  FOODS_3  FOODS     CA_1
# 2229  FOODS_3_004_CA_1_validation  FOODS_3_004  FOODS_3  FOODS     CA_1
# 2230  FOODS_3_005_CA_1_validation  FOODS_3_005  FOODS_3  FOODS     CA_1
#
#      state_id  d_338  d_339  d_340  d_341  ...  d_1820  d_1821  d_1822  \
# 2226       CA      3      0      0      0  ...       0       0       0
# 2227       CA      0      0      0      0  ...       1       3       6
# 2228       CA      0      0      0      0  ...       0       0       0
# 2229       CA      0      0      0      0  ...       0       2       3
# 2230       CA      2      0      3      2  ...       0       0       1
#
#       d_1823  d_1824  d_1825  d_1826  d_1827  d_1828  d_1829
# 2226       0       1       0       0       0       0       0
# 2227       3       0       1       2       2      10       4
# 2228       0       0       0       0       0       0       0
# 2229       0       1       1       1       0       1       0
# 2230       0       1       0       0       0       2       1
#
# [5 rows x 1498 columns]

# %%
mean_demand_stats = (
    df_wide_train_val
    .set_index(["id", "item_id", "dept_id", "cat_id", "store_id", "state_id"])
    .mean(axis=1)
    .agg(
        q_05=lambda s: s.quantile(q=0.05),
        q_10=lambda s: s.quantile(q=0.1),
        q_50=lambda s: s.quantile(q=0.5),        
        q_90=lambda s: s.quantile(q=0.9),
        q_95=lambda s: s.quantile(q=0.95),
        min=lambda s: s.min(),
        mean=lambda s: s.mean(),
        max=lambda s: s.max(),
        SD=lambda s: s.std(),
    )
)
mean_demand_stats
# Out:
# q_05     0.191823
# q_10     0.299330
# q_50     1.179625
# q_90     5.763539
# q_95     9.877078
# min      0.000000
# mean     2.618941
# max     72.782842
# SD       4.907627
# dtype: float64

# %%
lb_mean_demand = 0.15
ub_mean_demand = 0.5
sparse_series = (
    df_wide_train_val
    .set_index(["id", "item_id", "dept_id", "cat_id", "store_id", "state_id"])
    .mean(axis=1)
    [lambda mean_demand: mean_demand.between(lb_mean_demand, ub_mean_demand)]
)
print(sparse_series.shape)
sparse_series
# Out:
# (144,)
# id                           item_id      dept_id  cat_id  store_id  state_id
# FOODS_3_001_CA_1_validation  FOODS_3_001  FOODS_3  FOODS   CA_1      CA          0.374665
# FOODS_3_003_CA_1_validation  FOODS_3_003  FOODS_3  FOODS   CA_1      CA          0.214477
# FOODS_3_006_CA_1_validation  FOODS_3_006  FOODS_3  FOODS   CA_1      CA          0.179625
# FOODS_3_009_CA_1_validation  FOODS_3_009  FOODS_3  FOODS   CA_1      CA          0.207105
# FOODS_3_016_CA_1_validation  FOODS_3_016  FOODS_3  FOODS   CA_1      CA          0.417560
#                                                                                    ...
# FOODS_3_790_CA_1_validation  FOODS_3_790  FOODS_3  FOODS   CA_1      CA          0.263405
# FOODS_3_796_CA_1_validation  FOODS_3_796  FOODS_3  FOODS   CA_1      CA          0.244638
# FOODS_3_799_CA_1_validation  FOODS_3_799  FOODS_3  FOODS   CA_1      CA          0.180295
# FOODS_3_806_CA_1_validation  FOODS_3_806  FOODS_3  FOODS   CA_1      CA          0.305630
# FOODS_3_815_CA_1_validation  FOODS_3_815  FOODS_3  FOODS   CA_1      CA          0.389410
# Length: 144, dtype: float64

# %%
sparse_df = (
    df_wide_train_val
    .set_index(keys=["state_id",'store_id', 'item_id'])
    .loc[sparse_series.reset_index()[["state_id", 'store_id', 'item_id']].values.tolist()]
    .drop(columns=["id", "dept_id", "cat_id"])
)
sparse_df
# Out:
#                                d_338  d_339  d_340  d_341  d_342  d_343  \
# state_id store_id item_id
# CA       CA_1     FOODS_3_001      3      0      0      0      1      1
#                   FOODS_3_003      0      0      0      0      0      0
#                   FOODS_3_006      0      0      0      0      0      0
#                   FOODS_3_009      0      0      0      0      0      0
#                   FOODS_3_016      0      0      0      0      0      0
# ...                              ...    ...    ...    ...    ...    ...
#                   FOODS_3_790      0      0      0      0      0      0
#                   FOODS_3_796      0      0      0      0      0      0
#                   FOODS_3_799      0      0      0      1      0      2
#                   FOODS_3_806      0      0      0      0      0      0
#                   FOODS_3_815      0      0      0      0      0      0
#
#                                d_344  d_345  d_346  d_347  ...  d_1820  \
# state_id store_id item_id                                  ...
# CA       CA_1     FOODS_3_001      1      2      0      1  ...       0
#                   FOODS_3_003      0      0      0      0  ...       0
#                   FOODS_3_006      0      0      0      0  ...       0
#                   FOODS_3_009      0      0      0      0  ...       1
#                   FOODS_3_016      0      0      0      0  ...       3
# ...                              ...    ...    ...    ...  ...     ...
#                   FOODS_3_790      0      0      0      0  ...       0
#                   FOODS_3_796      0      0      0      0  ...       2
#                   FOODS_3_799      0      1      0      0  ...       0
#                   FOODS_3_806      0      0      0      0  ...       1
#                   FOODS_3_815      0      0      0      0  ...       0
#
#                                d_1821  d_1822  d_1823  d_1824  d_1825  d_1826  \
# state_id store_id item_id
# CA       CA_1     FOODS_3_001       0       0       0       1       0       0
#                   FOODS_3_003       0       0       0       0       0       0
#                   FOODS_3_006       0       0       0       0       0       1
#                   FOODS_3_009       0       0       1       3       1       1
#                   FOODS_3_016       5       3       1       0       2       5
# ...                               ...     ...     ...     ...     ...     ...
#                   FOODS_3_790       0       0       0       0       0       0
#                   FOODS_3_796       7       7       2       5       8       5
#                   FOODS_3_799       0       0       0       0       0       0
#                   FOODS_3_806       1       1       1       1       0       0
#                   FOODS_3_815       0       1       0       0       0       0
#
#                                d_1827  d_1828  d_1829
# state_id store_id item_id
# CA       CA_1     FOODS_3_001       0       0       0
#                   FOODS_3_003       0       0       0
#                   FOODS_3_006       0       1       3
#                   FOODS_3_009       0       1       2
#                   FOODS_3_016       0       5       3
# ...                               ...     ...     ...
#                   FOODS_3_790       0       0       0
#                   FOODS_3_796       5       2       7
#                   FOODS_3_799       0       0       0
#                   FOODS_3_806       2       0       3
#                   FOODS_3_815       1       0       0
#
# [144 rows x 1492 columns]

# %%
df_train_val = pd.wide_to_long(sparse_df.reset_index(), stubnames='d_', i=["state_id", "store_id", "item_id"], j='date')
df_train_val = (
    df_train_val
    .reset_index(level="date")
    # .reorder_levels(order=["state_id", "store_id", "item_id"])
    .rename(columns={"d_": "sales"})
)
df_train_val["date"] = df_train_val["date"].map(lambda el: day2date[f"d_{el}"])
df_train_val = df_train_val.set_index("date", append=True)

# %%
df_train_val.groupby("item_id")["sales"].transform(lambda s: s > 0)
# Out:
# state_id  store_id  item_id      date
# CA        CA_1      FOODS_3_001  2012-01-01     True
#                                  2012-01-02    False
#                                  2012-01-03    False
#                                  2012-01-04    False
#                                  2012-01-05     True
#                                                ...
#                     FOODS_3_815  2016-01-27    False
#                                  2016-01-28    False
#                                  2016-01-29     True
#                                  2016-01-30    False
#                                  2016-01-31    False
# Name: sales, Length: 214848, dtype: bool

# %%
df_train_val
# Out:
#                                           sales
# state_id store_id item_id     date
# CA       CA_1     FOODS_3_001 2012-01-01      3
#                               2012-01-02      0
#                               2012-01-03      0
#                               2012-01-04      0
#                               2012-01-05      1
# ...                                         ...
#                   FOODS_3_815 2016-01-27      0
#                               2016-01-28      0
#                               2016-01-29      1
#                               2016-01-30      0
#                               2016-01-31      0
#
# [214848 rows x 1 columns]

# %%
end_date - np.timedelta64(8 * 30 + 4, "D")
# Out:
# Timestamp('2015-06-01 00:00:00')

# %%
df_end_series_stats = (
    df_train_val
        .loc[pd.IndexSlice[:, :, :, end_date - np.timedelta64(8 * 30 + 4, "D"): end_date]]
        .groupby("item_id")
        .agg(
            mean_zeros= ('sales', lambda s: (s == 0).mean()),
            q85_sales=('sales', lambda s: s.quantile(q=0.85)),
            q90_sales=('sales', lambda s: s.quantile(q=0.9)),
            q95_sales=('sales', lambda s: s.quantile(q=0.95))
        )
        .sort_values(by="mean_zeros", ascending=False)
)

df_end_series_stats.head(30)
# Out:
#              mean_zeros  q85_sales  q90_sales  q95_sales
# item_id
# FOODS_3_790    1.000000        0.0        0.0        0.0
# FOODS_3_522    1.000000        0.0        0.0        0.0
# FOODS_3_762    1.000000        0.0        0.0        0.0
# FOODS_3_345    1.000000        0.0        0.0        0.0
# FOODS_3_549    1.000000        0.0        0.0        0.0
# FOODS_3_630    1.000000        0.0        0.0        0.0
# FOODS_3_153    0.967347        0.0        0.0        0.0
# FOODS_3_093    0.922449        0.0        0.0        1.0
# FOODS_3_799    0.914286        0.0        0.0        1.0
# FOODS_3_464    0.914286        0.0        0.0        1.0
# FOODS_3_347    0.910204        0.0        0.0        1.0
# FOODS_3_758    0.902041        0.0        0.0        1.0
# FOODS_3_457    0.902041        0.0        0.0        1.0
# FOODS_3_266    0.897959        0.0        0.6        1.0
# FOODS_3_554    0.885714        0.0        1.0        1.0
# FOODS_3_552    0.885714        0.0        1.0        1.0
# FOODS_3_188    0.881633        0.0        1.0        1.0
# FOODS_3_256    0.873469        0.0        1.0        1.0
# FOODS_3_510    0.857143        0.0        1.0        1.0
# FOODS_3_149    0.853061        0.0        1.0        1.0
# FOODS_3_017    0.840816        1.0        1.0        1.0
# FOODS_3_543    0.836735        1.0        1.0        1.0
# FOODS_3_364    0.832653        1.0        1.0        2.0
# FOODS_3_713    0.832653        1.0        1.0        1.8
# FOODS_3_268    0.832653        1.0        1.0        1.0
# FOODS_3_558    0.828571        1.0        1.0        1.8
# FOODS_3_745    0.820408        1.0        1.0        1.0
# FOODS_3_506    0.820408        1.0        1.0        1.0
# FOODS_3_122    0.812245        1.0        1.0        2.0
# FOODS_3_375    0.808163        1.0        1.0        2.0

# %%
df_end_series_stats = (
    df_train_val
        .loc[pd.IndexSlice[:, :, :, end_date - np.timedelta64(8 * 30 + 4, "D"): end_date]]
        .groupby("item_id")
        .agg(
            **{
                "mean_zeros": ('sales', lambda s: (s == 0).mean()),
                "q85_sales": ('sales', lambda s: s.quantile(q=0.85)),
                "q90_sales": ('sales', lambda s: s.quantile(q=0.9)),
                "q95_sales": ('sales', lambda s: s.quantile(q=0.95))
            }
        ) 
        .sort_values(by="mean_zeros", ascending=False)
)

df_end_series_stats.head(30)
# Out:
#              mean_zeros  q85_sales  q90_sales  q95_sales
# item_id
# FOODS_3_790    1.000000        0.0        0.0        0.0
# FOODS_3_522    1.000000        0.0        0.0        0.0
# FOODS_3_762    1.000000        0.0        0.0        0.0
# FOODS_3_345    1.000000        0.0        0.0        0.0
# FOODS_3_549    1.000000        0.0        0.0        0.0
# FOODS_3_630    1.000000        0.0        0.0        0.0
# FOODS_3_153    0.967347        0.0        0.0        0.0
# FOODS_3_093    0.922449        0.0        0.0        1.0
# FOODS_3_799    0.914286        0.0        0.0        1.0
# FOODS_3_464    0.914286        0.0        0.0        1.0
# FOODS_3_347    0.910204        0.0        0.0        1.0
# FOODS_3_758    0.902041        0.0        0.0        1.0
# FOODS_3_457    0.902041        0.0        0.0        1.0
# FOODS_3_266    0.897959        0.0        0.6        1.0
# FOODS_3_554    0.885714        0.0        1.0        1.0
# FOODS_3_552    0.885714        0.0        1.0        1.0
# FOODS_3_188    0.881633        0.0        1.0        1.0
# FOODS_3_256    0.873469        0.0        1.0        1.0
# FOODS_3_510    0.857143        0.0        1.0        1.0
# FOODS_3_149    0.853061        0.0        1.0        1.0
# FOODS_3_017    0.840816        1.0        1.0        1.0
# FOODS_3_543    0.836735        1.0        1.0        1.0
# FOODS_3_364    0.832653        1.0        1.0        2.0
# FOODS_3_713    0.832653        1.0        1.0        1.8
# FOODS_3_268    0.832653        1.0        1.0        1.0
# FOODS_3_558    0.828571        1.0        1.0        1.8
# FOODS_3_745    0.820408        1.0        1.0        1.0
# FOODS_3_506    0.820408        1.0        1.0        1.0
# FOODS_3_122    0.812245        1.0        1.0        2.0
# FOODS_3_375    0.808163        1.0        1.0        2.0

# %%
# remove items with too many zeros at the end of the series
bad_items = df_end_series_stats[lambda el: el['q85_sales'] == 0].index

# %%
df_train_val = df_train_val.loc[~df_train_val.index.get_level_values("item_id").isin(bad_items)].copy()
df_train_val.head()
# Out:
#                                           sales
# state_id store_id item_id     date
# CA       CA_1     FOODS_3_001 2012-01-01      3
#                               2012-01-02      0
#                               2012-01-03      0
#                               2012-01-04      0
#                               2012-01-05      1

# %%
sparse_df = sparse_df.loc[~sparse_df.index.get_level_values("item_id").isin(bad_items)].copy()

# %%
def intermittent_stats(demand_series: pd.Series):
    # mean of non-zero demands
    mean_nonzero_demand =  demand_series.loc[demand_series > 0].mean()
    median_nonzero_demand = demand_series.loc[demand_series > 0].median()
    SD_nonzero_demand = demand_series.loc[demand_series > 0].std()
    # CV^2- coefficient of variation squared
    cv_squared = (SD_nonzero_demand /mean_nonzero_demand) ** 2  # coefficient of variation
    # mean interval size between non-zero demands
    # * truncate series s.t. starts and ends with non-zero demand
    non_zero_idxes = np.arange(len(demand_series))[demand_series > 0] 
    # count intervals with zero demands (# 1 - non-zero to zero, 0- same value, -1 - zero to non-zero)
    intervals = [
        non_zero_idxes[i] - non_zero_idxes[i-1] 
        for i in range(1, len(non_zero_idxes)) 
        if non_zero_idxes[i] - non_zero_idxes[i-1] > 1
    ]
    intevel_series = pd.Series(intervals)
    
    return pd.Series(
        {
            "mean_nonzero_demand": mean_nonzero_demand,
            "median_nonzero_demand": median_nonzero_demand,
            "cv_squared": cv_squared,
            "mean_interval": intevel_series.mean(),
            "median_interval": intevel_series.median(),
            "q_90_interval": intevel_series.quantile(q=0.9),
            "q_95_interval": intevel_series.quantile(q=0.95),
        }
    ).round(3)


def intermittent_stats_old(demand_series: pd.Series):
    # mean of non-zero demands
    mean_nonzero_demand =  demand_series.loc[demand_series > 0].mean()
    median_nonzero_demand = demand_series.loc[demand_series > 0].median()
    SD_nonzero_demand = demand_series.loc[demand_series > 0].std()
    # CV^2- coefficient of variation squared
    cv_squared = (SD_nonzero_demand /mean_nonzero_demand) ** 2  # coefficient of variation
    # mean interval size between non-zero demands
    # * truncate series s.t. starts and ends with non-zero demand
    int_series = demand_series.loc[demand_series[(demand_series > 0)].idxmin():demand_series.cumsum().idxmax()]  
    # count intervals with zero demands (# 1 - non-zero to zero, 0- same value, -1 - zero to non-zero)
    intervals = ((int_series == 0).astype(int).diff() == 1).sum()
    mean_interval = (int_series == 0).sum() / intervals
    return pd.Series(
        {
            "mean_nonzero_demand": mean_nonzero_demand,
            "median_nonzero_demand": median_nonzero_demand,
            "cv_squared": cv_squared,
            "mean_interval": mean_interval.item()
        }
    ).round(3)

# %%
def plot_item(df: pd.DataFrame, store_id: str, item_id: str):
    (
        pd.pivot_table(
            data=df.loc[pd.IndexSlice[:, store_id,item_id,:], :].reset_index(),
            index="date",
            columns="item_id",
            values="sales"
        )
        .plot()
        
    )
    plt.figure().autofmt_xdate()
    plt.show()

# %%
sparse_df.apply(intermittent_stats , axis=1).sort_values(by="cv_squared", ascending=False)
# Out:
#                                mean_nonzero_demand  median_nonzero_demand  \
# state_id store_id item_id
# CA       CA_1     FOODS_3_315                2.434                    2.0
#                   FOODS_3_204                1.963                    1.0
#                   FOODS_3_421                2.298                    1.0
#                   FOODS_3_633                2.172                    1.0
#                   FOODS_3_777                2.031                    1.0
# ...                                            ...                    ...
#                   FOODS_3_244                1.298                    1.0
#                   FOODS_3_691                1.357                    1.0
#                   FOODS_3_180                1.222                    1.0
#                   FOODS_3_724                1.139                    1.0
#                   FOODS_3_017                1.085                    1.0
#
#                                cv_squared  mean_interval  median_interval  \
# state_id store_id item_id
# CA       CA_1     FOODS_3_315       1.034          9.390              3.0
#                   FOODS_3_204       0.966          5.149              3.0
#                   FOODS_3_421       0.845          5.274              3.0
#                   FOODS_3_633       0.832         10.077              3.0
#                   FOODS_3_777       0.831          4.416              3.0
# ...                                   ...            ...              ...
#                   FOODS_3_244       0.201          4.699              3.0
#                   FOODS_3_691       0.183          3.557              3.0
#                   FOODS_3_180       0.170          4.955              3.0
#                   FOODS_3_724       0.116          6.538              5.0
#                   FOODS_3_017       0.082          8.039              5.0
#
#                                q_90_interval  q_95_interval
# state_id store_id item_id
# CA       CA_1     FOODS_3_315            8.0          13.00
#                   FOODS_3_204            8.0          12.00
#                   FOODS_3_421            9.0          14.00
#                   FOODS_3_633           16.5          48.25
#                   FOODS_3_777            7.0          13.20
# ...                                      ...            ...
#                   FOODS_3_244            8.0          10.00
#                   FOODS_3_691            5.0           8.50
#                   FOODS_3_180            8.0          10.00
#                   FOODS_3_724           12.0          17.00
#                   FOODS_3_017           16.0          22.10
#
# [124 rows x 7 columns]

# %%
plot_item(df_train_val, store_id="CA_1", item_id="FOODS_3_001")

# %%
plot_item(df_train_val, store_id="CA_1", item_id="FOODS_3_315")

# %%
plot_item(df_train_val, store_id="CA_1", item_id="FOODS_3_633")

# %%
def create_similar_items_dict(similar_items: pd.Index, similarity_values: np.ndarray) -> dict:
    similar_items_dict = {}
    [
        similar_items_dict.update(
            {f"similar_item_{i}": similar_item , f"similar_value_{i}" : similar_value}
        )
        for i, (similar_item, similar_value) in enumerate(zip(similar_items, similarity_values), start=1)
    ]
    return similar_items_dict



def corr_stats(series_corr: pd.Series, n: int=5) -> pd.Series:
    item_id = series_corr.name[-1]
    similarity_series = series_corr.nlargest(n=n).round(4)
    similar_items = similarity_series.index.get_level_values(level="item_id")
    similarity_values = similarity_series.values
    similar_items_dict = create_similar_items_dict(similar_items, similarity_values)
    # print(similar_items_dict)
    return pd.Series(similar_items_dict)


def plot_corr_items(df: pd.DataFrame, store_id: str, item_id_lst: list[str], **plt_args):
    (
        pd.pivot_table(
            data=df.loc[pd.IndexSlice[:, store_id,item_id_lst,:], :].reset_index(),
            index="date",
            columns="item_id",
            values="sales"
        )
        .plot(subplots=plt_args.get("subplots", False), alpha=plt_args.get("alpha", 0.7)))
    plt.show()

# %%
# Compute cosine similarity
series_corr = cosine_similarity(sparse_df)
series_corr -= np.identity(n=series_corr.shape[0])
corr_df = pd.DataFrame(series_corr, index=sparse_df.index, columns=sparse_df.index).round(4)  # .agg([min, max], axis=1).sort_values(by="max", ascending=False).head(10)
# corr_func = partial(corr_stats, idxes=corr_df.index)
complementary_items_df = corr_df.apply(corr_stats, axis=1)

# %%
complementary_items_df.sort_values(by="similar_value_1", ascending=False)
# Out:
#                               similar_item_1  similar_value_1 similar_item_2  \
# state_id store_id item_id
# CA       CA_1     FOODS_3_806    FOODS_3_143           0.5471    FOODS_3_780
#                   FOODS_3_143    FOODS_3_806           0.5471    FOODS_3_018
#                   FOODS_3_602    FOODS_3_147           0.5344    FOODS_3_647
#                   FOODS_3_147    FOODS_3_602           0.5344    FOODS_3_003
#                   FOODS_3_003    FOODS_3_147           0.5221    FOODS_3_047
# ...                                      ...              ...            ...
#                   FOODS_3_713    FOODS_3_781           0.2459    FOODS_3_452
#                   FOODS_3_421    FOODS_3_158           0.2454    FOODS_3_340
#                   FOODS_3_001    FOODS_3_781           0.2447    FOODS_3_593
#                   FOODS_3_815    FOODS_3_416           0.2408    FOODS_3_442
#                   FOODS_3_017    FOODS_3_558           0.2253    FOODS_3_649
#
#                                similar_value_2 similar_item_3  \
# state_id store_id item_id
# CA       CA_1     FOODS_3_806           0.2938    FOODS_3_360
#                   FOODS_3_143           0.3253    FOODS_3_780
#                   FOODS_3_602           0.3823    FOODS_3_691
#                   FOODS_3_147           0.5221    FOODS_3_047
#                   FOODS_3_003           0.4340    FOODS_3_119
# ...                                        ...            ...
#                   FOODS_3_713           0.2385    FOODS_3_593
#                   FOODS_3_421           0.2413    FOODS_3_442
#                   FOODS_3_001           0.2353    FOODS_3_380
#                   FOODS_3_815           0.2333    FOODS_3_427
#                   FOODS_3_017           0.2179    FOODS_3_036
#
#                                similar_value_3 similar_item_4  \
# state_id store_id item_id
# CA       CA_1     FOODS_3_806           0.2839    FOODS_3_341
#                   FOODS_3_143           0.3165    FOODS_3_416
#                   FOODS_3_602           0.3792    FOODS_3_003
#                   FOODS_3_147           0.4456    FOODS_3_647
#                   FOODS_3_003           0.4249    FOODS_3_735
# ...                                        ...            ...
#                   FOODS_3_713           0.2310    FOODS_3_558
#                   FOODS_3_421           0.2255    FOODS_3_244
#                   FOODS_3_001           0.2333    FOODS_3_556
#                   FOODS_3_815           0.2262    FOODS_3_779
#                   FOODS_3_017           0.2075    FOODS_3_145
#
#                                similar_value_4 similar_item_5  similar_value_5
# state_id store_id item_id
# CA       CA_1     FOODS_3_806           0.2564    FOODS_3_710           0.2534
#                   FOODS_3_143           0.2849    FOODS_3_085           0.2837
#                   FOODS_3_602           0.3789    FOODS_3_278           0.3593
#                   FOODS_3_147           0.4331    FOODS_3_735           0.4114
#                   FOODS_3_003           0.4224    FOODS_3_390           0.4116
# ...                                        ...            ...              ...
#                   FOODS_3_713           0.2290    FOODS_3_539           0.2216
#                   FOODS_3_421           0.2222    FOODS_3_396           0.2211
#                   FOODS_3_001           0.2312    FOODS_3_506           0.2226
#                   FOODS_3_815           0.2255    FOODS_3_221           0.2244
#                   FOODS_3_017           0.2065    FOODS_3_593           0.2037
#
# [124 rows x 10 columns]

# %%
plot_corr_items(df=df_train_val, store_id="CA_1", item_id_lst=["FOODS_3_806", "FOODS_3_143"])

# %%
plot_corr_items(df=df_train_val, store_id="CA_1", item_id_lst=["FOODS_3_602", "FOODS_3_147"], subplots=True)

# %%
plot_corr_items(df=df_train_val, store_id="CA_1", item_id_lst=["FOODS_3_003", "FOODS_3_147"], subplots=True)

# %%
monthly_mean_sales = (
    df_train_val
    .reset_index(level="date")
    .groupby(["store_id", "item_id", pd.Grouper(key="date", freq="ME")])
    .mean()
)

monthly_mean_sales
# Out:
#                                     sales
# store_id item_id     date
# CA_1     FOODS_3_001 2012-01-31  0.838710
#                      2012-02-29  0.482759
#                      2012-03-31  0.645161
#                      2012-04-30  0.533333
#                      2012-05-31  0.322581
# ...                                   ...
#          FOODS_3_815 2015-09-30  1.000000
#                      2015-10-31  0.870968
#                      2015-11-30  0.566667
#                      2015-12-31  0.322581
#                      2016-01-31  0.354839
#
# [6076 rows x 1 columns]

# %%
def monthly_changes(monthly_diff_series: pd.Series, n_splits: int=8):
    splits = np.array_split(monthly_diff_series, n_splits)  # split into n sub-arrays
    changes_dict = {}
    changes_dict[f'pos_changes_total'] = (monthly_diff_series > 0).sum().item()
    changes_dict[f'neg_changes_total'] = (monthly_diff_series < 0).sum().item()
    for i, split in enumerate(splits):
        pos_changes = (split > 0).sum().item()
        changes_dict[f'pos_changes_{i}'] = pos_changes
        neg_changes = (split < 0).sum().item()
        changes_dict[f'neg_changes_{i}'] = neg_changes
    return pd.Series(changes_dict)

# %%
start_date, end_date
# Out:
# (Timestamp('2012-01-01 00:00:00'), Timestamp('2016-01-31 00:00:00'))

# %%
monthly_mean_sales.groupby(["store_id", "item_id"]).transform(lambda s: s.diff())
# Out:
#                                     sales
# store_id item_id     date
# CA_1     FOODS_3_001 2012-01-31       NaN
#                      2012-02-29 -0.355951
#                      2012-03-31  0.162403
#                      2012-04-30 -0.111828
#                      2012-05-31 -0.210753
# ...                                   ...
#          FOODS_3_815 2015-09-30  0.516129
#                      2015-10-31 -0.129032
#                      2015-11-30 -0.304301
#                      2015-12-31 -0.244086
#                      2016-01-31  0.032258
#
# [6076 rows x 1 columns]

# %%
monthly_diff_sales = monthly_mean_sales.groupby(["store_id", "item_id"]).transform(lambda s: s.diff())

# %%
def apply_sign_pct_change(s: pd.Series) -> float:
    max_change = s[['pos_changes_total', 'neg_changes_total']].max()
    min_change = s[['pos_changes_total', 'neg_changes_total']].min()
    return (max_change - min_change) / min_change

# %%
monthly_diff_stats = monthly_diff_sales.groupby(["store_id", "item_id"]).apply(monthly_changes)
monthly_diff_stats['sign_pct_change'] = monthly_diff_stats.apply(apply_sign_pct_change, axis=1)
# Out:
# /Users/galkampel/Desktop/Projects/m5_forecasting/.venv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %%
monthly_diff_stats.sort_values(by="sign_pct_change", ascending=False).head(10)
# Out:
#                       pos_changes_total  neg_changes_total  pos_changes_0  \
# store_id item_id
# CA_1     FOODS_3_563                  8                  2              0
#          FOODS_3_366                 10                  3              0
#          FOODS_3_147                  6                  2              0
#          FOODS_3_796                  6                  2              0
#          FOODS_3_119                  9                  4              0
#          FOODS_3_278                  9                  4              0
#          FOODS_3_166                  9                  4              0
#          FOODS_3_701                 12                  6              0
#          FOODS_3_262                 13                  7              0
#          FOODS_3_337                 11                  6              0
#
#                       neg_changes_0  pos_changes_1  neg_changes_1  \
# store_id item_id
# CA_1     FOODS_3_563              0              0              0
#          FOODS_3_366              0              0              0
#          FOODS_3_147              0              0              0
#          FOODS_3_796              0              0              0
#          FOODS_3_119              0              0              0
#          FOODS_3_278              0              0              0
#          FOODS_3_166              0              0              0
#          FOODS_3_701              0              0              0
#          FOODS_3_262              0              0              0
#          FOODS_3_337              0              0              0
#
#                       pos_changes_2  neg_changes_2  pos_changes_3  \
# store_id item_id
# CA_1     FOODS_3_563              0              0              0
#          FOODS_3_366              0              0              0
#          FOODS_3_147              0              0              0
#          FOODS_3_796              0              0              0
#          FOODS_3_119              0              0              0
#          FOODS_3_278              0              0              0
#          FOODS_3_166              0              0              0
#          FOODS_3_701              0              0              0
#          FOODS_3_262              0              0              0
#          FOODS_3_337              0              0              0
#
#                       neg_changes_3  pos_changes_4  neg_changes_4  \
# store_id item_id
# CA_1     FOODS_3_563              0              0              0
#          FOODS_3_366              0              0              0
#          FOODS_3_147              0              0              0
#          FOODS_3_796              0              0              0
#          FOODS_3_119              0              0              0
#          FOODS_3_278              0              0              0
#          FOODS_3_166              0              0              0
#          FOODS_3_701              0              0              0
#          FOODS_3_262              0              2              0
#          FOODS_3_337              0              0              0
#
#                       pos_changes_5  neg_changes_5  pos_changes_6  \
# store_id item_id
# CA_1     FOODS_3_563              1              0              2
#          FOODS_3_366              1              0              4
#          FOODS_3_147              0              0              5
#          FOODS_3_796              0              0              1
#          FOODS_3_119              1              0              4
#          FOODS_3_278              1              0              4
#          FOODS_3_166              1              0              5
#          FOODS_3_701              4              2              3
#          FOODS_3_262              3              3              4
#          FOODS_3_337              4              1              4
#
#                       neg_changes_6  pos_changes_7  neg_changes_7  \
# store_id item_id
# CA_1     FOODS_3_563              1              5              1
#          FOODS_3_366              2              5              1
#          FOODS_3_147              0              1              2
#          FOODS_3_796              1              5              1
#          FOODS_3_119              2              4              2
#          FOODS_3_278              2              4              2
#          FOODS_3_166              1              3              3
#          FOODS_3_701              3              5              1
#          FOODS_3_262              2              4              2
#          FOODS_3_337              2              3              3
#
#                       sign_pct_change
# store_id item_id
# CA_1     FOODS_3_563         3.000000
#          FOODS_3_366         2.333333
#          FOODS_3_147         2.000000
#          FOODS_3_796         2.000000
#          FOODS_3_119         1.250000
#          FOODS_3_278         1.250000
#          FOODS_3_166         1.250000
#          FOODS_3_701         1.000000
#          FOODS_3_262         0.857143
#          FOODS_3_337         0.833333

# %%
monthly_diff_stats.query("pos_changes_7 == 0 and neg_changes_7 == 0")
# Out:
# Empty DataFrame
# Columns: [pos_changes_total, neg_changes_total, pos_changes_0, neg_changes_0, pos_changes_1, neg_changes_1, pos_changes_2, neg_changes_2, pos_changes_3, neg_changes_3, pos_changes_4, neg_changes_4, pos_changes_5, neg_changes_5, pos_changes_6, neg_changes_6, pos_changes_7, neg_changes_7, sign_pct_change]
# Index: []

# %%
monthly_diff_stats.query("pos_changes_total < neg_changes_total").sort_values(by="sign_pct_change", ascending=False).head(10)
# Out:
#                       pos_changes_total  neg_changes_total  pos_changes_0  \
# store_id item_id
# CA_1     FOODS_3_164                  7                 12              0
#          FOODS_3_677                 14                 23              0
#          FOODS_3_145                 18                 29              2
#          FOODS_3_038                  5                  8              0
#          FOODS_3_647                  5                  8              0
#          FOODS_3_691                  8                 12              0
#          FOODS_3_360                 15                 22              0
#          FOODS_3_315                 11                 16              0
#          FOODS_3_364                  9                 13              0
#          FOODS_3_001                 17                 24              1
#
#                       neg_changes_0  pos_changes_1  neg_changes_1  \
# store_id item_id
# CA_1     FOODS_3_164              0              0              0
#          FOODS_3_677              3              0              0
#          FOODS_3_145              4              1              4
#          FOODS_3_038              0              0              0
#          FOODS_3_647              0              0              0
#          FOODS_3_691              0              0              0
#          FOODS_3_360              0              1              1
#          FOODS_3_315              2              0              0
#          FOODS_3_364              0              0              0
#          FOODS_3_001              4              2              4
#
#                       pos_changes_2  neg_changes_2  pos_changes_3  \
# store_id item_id
# CA_1     FOODS_3_164              0              0              0
#          FOODS_3_677              3              1              2
#          FOODS_3_145              3              3              2
#          FOODS_3_038              0              0              0
#          FOODS_3_647              0              0              0
#          FOODS_3_691              0              0              0
#          FOODS_3_360              2              3              2
#          FOODS_3_315              2              4              2
#          FOODS_3_364              0              0              1
#          FOODS_3_001              2              3              3
#
#                       neg_changes_3  pos_changes_4  neg_changes_4  \
# store_id item_id
# CA_1     FOODS_3_164              0              1              0
#          FOODS_3_677              4              2              4
#          FOODS_3_145              4              2              4
#          FOODS_3_038              0              0              0
#          FOODS_3_647              0              0              0
#          FOODS_3_691              0              1              1
#          FOODS_3_360              4              2              4
#          FOODS_3_315              4              0              1
#          FOODS_3_364              0              2              4
#          FOODS_3_001              2              2              2
#
#                       pos_changes_5  neg_changes_5  pos_changes_6  \
# store_id item_id
# CA_1     FOODS_3_164              2              4              2
#          FOODS_3_677              2              4              3
#          FOODS_3_145              3              3              2
#          FOODS_3_038              1              0              2
#          FOODS_3_647              1              0              3
#          FOODS_3_691              2              4              4
#          FOODS_3_360              3              3              4
#          FOODS_3_315              1              0              4
#          FOODS_3_364              3              2              2
#          FOODS_3_001              3              3              2
#
#                       neg_changes_6  pos_changes_7  neg_changes_7  \
# store_id item_id
# CA_1     FOODS_3_164              4              2              4
#          FOODS_3_677              3              2              4
#          FOODS_3_145              4              3              3
#          FOODS_3_038              4              2              4
#          FOODS_3_647              3              1              5
#          FOODS_3_691              2              1              5
#          FOODS_3_360              2              1              5
#          FOODS_3_315              1              2              4
#          FOODS_3_364              4              1              3
#          FOODS_3_001              3              2              3
#
#                       sign_pct_change
# store_id item_id
# CA_1     FOODS_3_164         0.714286
#          FOODS_3_677         0.642857
#          FOODS_3_145         0.611111
#          FOODS_3_038         0.600000
#          FOODS_3_647         0.600000
#          FOODS_3_691         0.500000
#          FOODS_3_360         0.466667
#          FOODS_3_315         0.454545
#          FOODS_3_364         0.444444
#          FOODS_3_001         0.411765

# %%
plot_item(df=df_train_val, store_id="CA_1", item_id="FOODS_3_164")

# %%
plot_item(df=df_train_val, store_id="CA_1", item_id="FOODS_3_677")

# %%
df_train_val.index.get_level_values("item_id").nunique()
# Out:
# 124

# %%
df_calendar = df_calendar.loc[df_calendar['date'].between(start_date, end_date)].copy()
df_calendar.head()
# Out:
#           date  wm_yr_wk    weekday  week_of_year  month  year      d  \
# 337 2012-01-01     11149     Sunday            52      1  2012  d_338
# 338 2012-01-02     11149     Monday             1      1  2012  d_339
# 339 2012-01-03     11149    Tuesday             1      1  2012  d_340
# 340 2012-01-04     11149  Wednesday             1      1  2012  d_341
# 341 2012-01-05     11149   Thursday             1      1  2012  d_342
#
#     event_name  event  snap_CA  snap_TX  snap_WI
# 337    NewYear      1        1        1        0
# 338   No Event      0        1        0        1
# 339   No Event      0        1        1        1
# 340   No Event      0        1        0        0
# 341   No Event      0        1        1        1

# %%
items = df_train_val.index.get_level_values("item_id").unique()

# %%
df_prices = df_prices.query("item_id in @items")

# %%
price_df = (
    pd.merge(df_prices, df_calendar.reset_index()[["wm_yr_wk", "date"]], on="wm_yr_wk")
    .set_index(["store_id", "item_id", "date"])
    .drop(columns="wm_yr_wk")
    .sort_index()
)
price_df
# Out:
#                                  sell_price
# store_id item_id     date
# CA_1     FOODS_3_001 2012-01-01         2.5
#                      2012-01-02         2.5
#                      2012-01-03         2.5
#                      2012-01-04         2.5
#                      2012-01-05         2.5
# ...                                     ...
# WI_3     FOODS_3_827 2016-01-27         1.0
#                      2016-01-28         1.0
#                      2016-01-29         1.0
#                      2016-01-30         1.0
#                      2016-01-31         1.0
#
# [3037160 rows x 1 columns]

# %%
df_cal = (
    pd.wide_to_long(
        df_calendar.drop(columns=["d"]), 
        stubnames='snap_',
        i=["date"],
        j='state_id',
        suffix="\\D+"
    )
    .reorder_levels(order=["state_id", "date"])  # reorder index level
    .rename(columns={"snap_": "snap"}))
df_cal
# Out:
#                      event event_name  month  week_of_year    weekday  \
# state_id date
# CA       2012-01-01      1    NewYear      1            52     Sunday
#          2012-01-02      0   No Event      1             1     Monday
#          2012-01-03      0   No Event      1             1    Tuesday
#          2012-01-04      0   No Event      1             1  Wednesday
#          2012-01-05      0   No Event      1             1   Thursday
# ...                    ...        ...    ...           ...        ...
# WI       2016-01-27      0   No Event      1             4  Wednesday
#          2016-01-28      0   No Event      1             4   Thursday
#          2016-01-29      0   No Event      1             4     Friday
#          2016-01-30      0   No Event      1             4   Saturday
#          2016-01-31      0   No Event      1             4     Sunday
#
#                      wm_yr_wk  year  snap
# state_id date
# CA       2012-01-01     11149  2012     1
#          2012-01-02     11149  2012     1
#          2012-01-03     11149  2012     1
#          2012-01-04     11149  2012     1
#          2012-01-05     11149  2012     1
# ...                       ...   ...   ...
# WI       2016-01-27     11552  2016     0
#          2016-01-28     11552  2016     0
#          2016-01-29     11552  2016     0
#          2016-01-30     11601  2016     0
#          2016-01-31     11601  2016     0
#
# [4476 rows x 8 columns]

# %%
df_train_val.head(2)
# Out:
#                                           sales
# state_id store_id item_id     date
# CA       CA_1     FOODS_3_001 2012-01-01      3
#                               2012-01-02      0

# %%
df_train_val.loc[pd.IndexSlice[:, :, :, end_date - np.timedelta64(6 * 30, "D"): end_date]]
# Out:
#                                           sales
# state_id store_id item_id     date
# CA       CA_1     FOODS_3_001 2015-08-04      0
#                               2015-08-05      0
#                               2015-08-06      0
#                               2015-08-07      0
#                               2015-08-08      0
# ...                                         ...
#                   FOODS_3_815 2016-01-27      0
#                               2016-01-28      0
#                               2016-01-29      1
#                               2016-01-30      0
#                               2016-01-31      0
#
# [26064 rows x 1 columns]

# %%
X_price = (
    df_train_val
    .merge(price_df, on=["store_id", "item_id", "date"], how="left")
    .drop(columns="sales")
    .fillna(value=0.0)
    .set_index(df_train_val.index)
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 3
#       1 X_price = (
#       2     df_train_val
# ----> 3     .merge(price_df, on=["store_id", "item_id", "date"], how="left")
#       4     .drop(columns="sales")
#       5     .fillna(value=0.0)
#       6     .set_index(df_train_val.index)
#       7 )
#
# NameError: name 'price_df' is not defined

# %%
X_price.head()
# Out:
#                                           sell_price
# state_id store_id item_id     date
# CA       CA_1     FOODS_3_003 2012-01-01         0.0
#                               2012-01-02         0.0
#                               2012-01-03         0.0
#                               2012-01-04         0.0
#                               2012-01-05         0.0

# %%
X_price
# Out:
#                                           sell_price
# state_id store_id item_id     date
# CA       CA_1     FOODS_3_003 2012-01-01        0.00
#                               2012-01-02        0.00
#                               2012-01-03        0.00
#                               2012-01-04        0.00
#                               2012-01-05        0.00
# ...                                              ...
# WI       WI_3     FOODS_3_815 2016-01-27        2.48
#                               2016-01-28        2.48
#                               2016-01-29        2.48
#                               2016-01-30        2.48
#                               2016-01-31        2.48
#
# [938468 rows x 1 columns]

# %%
cols = ["weekday", "month", "year", "event_name", "sell_price"]
X = (
    X_price
    .merge(df_cal, on=["state_id", "date"])
    .set_index(X_price.index)
)
X = X[cols]
X.insert()
X
# Out:
#                                             weekday  month  year event_name  \
# state_id store_id item_id     date
# CA       CA_1     FOODS_3_003 2012-01-01     Sunday      1  2012    NewYear
#                               2012-01-02     Monday      1  2012   No Event
#                               2012-01-03    Tuesday      1  2012   No Event
#                               2012-01-04  Wednesday      1  2012   No Event
#                               2012-01-05   Thursday      1  2012   No Event
# ...                                             ...    ...   ...        ...
# WI       WI_3     FOODS_3_815 2016-01-27  Wednesday      1  2016   No Event
#                               2016-01-28   Thursday      1  2016   No Event
#                               2016-01-29     Friday      1  2016   No Event
#                               2016-01-30   Saturday      1  2016   No Event
#                               2016-01-31     Sunday      1  2016   No Event
#
#                                           sell_price
# state_id store_id item_id     date
# CA       CA_1     FOODS_3_003 2012-01-01        0.00
#                               2012-01-02        0.00
#                               2012-01-03        0.00
#                               2012-01-04        0.00
#                               2012-01-05        0.00
# ...                                              ...
# WI       WI_3     FOODS_3_815 2016-01-27        2.48
#                               2016-01-28        2.48
#                               2016-01-29        2.48
#                               2016-01-30        2.48
#                               2016-01-31        2.48
#
# [938468 rows x 5 columns]

# %%
y = df_train_val[['sales']]

# %%
y
# Out:
#                                           sales
# state_id store_id item_id     date
# CA       CA_1     FOODS_3_003 2012-01-01      0
#                               2012-01-02      0
#                               2012-01-03      0
#                               2012-01-04      0
#                               2012-01-05      0
# ...                                         ...
# WI       WI_3     FOODS_3_815 2016-01-27      0
#                               2016-01-28      0
#                               2016-01-29      0
#                               2016-01-30      0
#                               2016-01-31      0
#
# [938468 rows x 1 columns]

# %%
from sktime.forecasting.model_selection import temporal_train_test_split
from sktime.split import ExpandingWindowSplitter
from sktime.utils import plot_series, plot_windows

from sktime.transformations.compose import Id, FeatureUnion, TransformerPipeline, ColumnEnsembleTransformer
from sktime.transformations.series.adapt import TabularToSeriesAdaptor
from sklearn.preprocessing import OneHotEncoder

# %%
from sklearn.base import BaseEstimator, TransformerMixin
# from sktime.forecasting.compose import RecursiveTabularRegressionForecaster, ForecastingPipeline, make_reduction
from sktime.transformations.series.summarize import WindowSummarizer
from sktime.forecasting.compose import make_reduction
from sktime.forecasting.naive import NaiveForecaster
from typing import Optional

# %%
from sktime.performance_metrics.forecasting import (
    MeanAbsoluteError,
    MeanSquaredError
)
from sktime.forecasting.model_evaluation import evaluate

# %%
class OHEwithBaseline(OneHotEncoder):

    def __init__(self, baseline_category: str, drop_first: bool=False):
        self.baseline_category = baseline_category
        self.drop_first = drop_first
        self.ohe = OneHotEncoder(drop='first' if self.drop_first else None, sparse_output=False)

    def fit(self, X: np.ndarray | pd.DataFrame, y: Optional[pd.Series]=None):
        self.ohe.fit(X)
        categories_ = self.ohe.categories_[0].tolist()
        categories_.remove(self.baseline_category)
        categories_.insert(0,self.baseline_category)
        self.ohe.categories_[0] = np.array(categories_)
        return self

    def transform(self, X: np.ndarray | pd.DataFrame, y: Optional[pd.Series]=None) -> pd.DataFrame:
        X = self.ohe.transform(X)
        return X

    def inverse_transform(self, X: pd.DataFrame) -> pd.DataFrame:
        X_transform = self.ohe.inverse_transform(X)
        return X_transform

    def get_feature_names_out(self, *args, **params):
        return self.ohe.get_feature_names_out()

# %%
X_train.shape, X_test.shape
# Out:
# ((918969, 5), (19499, 5))

# %%
X_train.tail()
# Out:
#                                             weekday  month  year event_name  \
# state_id store_id item_id     date
# WI       WI_3     FOODS_3_815 2015-12-27     Sunday     12  2015   No Event
#                               2015-12-28     Monday     12  2015   No Event
#                               2015-12-29    Tuesday     12  2015   No Event
#                               2015-12-30  Wednesday     12  2015   No Event
#                               2015-12-31   Thursday     12  2015   No Event
#
#                                           sell_price
# state_id store_id item_id     date
# WI       WI_3     FOODS_3_815 2015-12-27        2.48
#                               2015-12-28        2.48
#                               2015-12-29        2.48
#                               2015-12-30        2.48
#                               2015-12-31        2.48

# %%
X_test.head()
# Out:
#                                            weekday  month  year event_name  \
# state_id store_id item_id     date
# CA       CA_1     FOODS_3_003 2016-01-01    Friday      1  2016    NewYear
#                               2016-01-02  Saturday      1  2016   No Event
#                               2016-01-03    Sunday      1  2016   No Event
#                               2016-01-04    Monday      1  2016   No Event
#                               2016-01-05   Tuesday      1  2016   No Event
#
#                                           sell_price
# state_id store_id item_id     date
# CA       CA_1     FOODS_3_003 2016-01-01        3.98
#                               2016-01-02        3.98
#                               2016-01-03        3.98
#                               2016-01-04        3.98
#                               2016-01-05        3.98

# %%
y_train, y_test, X_train, X_test = temporal_train_test_split(y, X, test_size=31)

# %%
cv = ExpandingWindowSplitter(
    fh=np.arange(1, 31), initial_window=int(365 * 2), step_length=30
)

# %%
plot_windows(
    cv=cv,
    y=y_train.xs(("CA_1", "FOODS_3_003"), level=("store_id", "item_id")).reset_index(level="state_id", drop=True)
)
plt.show()

# %%
column_transformer = ColumnEnsembleTransformer(
    transformers=[
        (
            "ohe_week",
            TabularToSeriesAdaptor(OHEwithBaseline(baseline_category="Monday", drop_first=True).set_output(transform="pandas"), input_type="pandas"),
            ["weekday"]
        ),
        (
            "ohe_month",
            TabularToSeriesAdaptor(OHEwithBaseline(baseline_category=1, drop_first=True).set_output(transform="pandas"), input_type="pandas"),
            ["month"]
        ),
        # (
        #     "ohe_year",
        #     TabularToSeriesAdaptor(OHEwithBaseline(baseline_category=2012, drop_first=True).set_output(transform="pandas"), input_type="pandas"),
        #     ["year"]
        # ),
        (
            "ohe_event",
            TabularToSeriesAdaptor(OHEwithBaseline(baseline_category='No Event', drop_first=True).set_output(transform="pandas"), input_type="pandas"),
            ["event_name"]
        )
    ],
    remainder="passthrough",
    feature_names_out="original"
)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr_forecaster = make_reduction(
        estimator=LinearRegression(),
        transformers=[WindowSummarizer(lag_feature={"lag": [1, 7, 30]})],   # add a lag feature
        strategy="recursive",
        pooling="global",
        window_length=None
)

lr_pipe = column_transformer ** lr_forecaster

# baseline- naive (weekly seasonal, last prediction)
nc_model = NaiveForecaster(sp=1)
# naive seasonal model with weekly seasonality 7
ns_model = NaiveForecaster(sp=7)

# %%
mae = MeanAbsoluteError()
rmse = MeanSquaredError(square_root=True)

scoring = [mae, rmse]

# %%
lr_results = evaluate(lr_pipe, cv=cv, y=y_train, X=X_train, scoring=scoring, return_model=False)
lr_results
# Out:
# /Users/galkampel/Desktop/Projects/m5_forecasting/.venv/lib/python3.12/site-packages/sktime/utils/parallel.py:107: FitFailedWarning:
#                 In evaluate, fitting of forecaster ForecastingPipeline failed,
#                 you can set error_score='raise' in evaluate to see
#                 the exception message.
#                 Fit failed for the 0-th data split, on training data y_train with
#                 cutoff <NA>, and len(y_train)=459170.
#                 The score will be set to nan.
#                 Failed forecaster with parameters: ForecastingPipeline(steps=[ColumnEnsembleTransformer(feature_names_out='original',
#                                                      remainder='passthrough',
#                                                      transformers=[('ohe_week',
#                                                                     TabularToSeriesAdaptor(input_type='pandas',
#                                                                                            transformer=OHEwithBaseline(baseline_category='Monday', drop_first=True)),
#                                                                     ['weekday']),
#                                                                    ('ohe_month',
#                                                                     TabularToSeriesAdaptor(input_type='pandas',
#                                                                                            transformer=OHEwithBaseline(basel...
#                                                                                            transformer=OHEwithBaseline(baseline_category=2012, drop_first=True)),
#                                                                     ['year']),
#                                                                    ('ohe_event',
#                                                                     TabularToSeriesAdaptor(input_type='pandas',
#                                                                                            transformer=OHEwithBaseline(baseline_category='No Event', drop_first=True)),
#                                                                     ['event_name'])]),
#                            RecursiveTabularRegressionForecaster(estimator=LinearRegression(),
#                                                                 pooling='global',
#                                                                 transformers=[WindowSummarizer(lag_feature={'lag': [1,
#                                                                                                                     7,
#                                                                                                                     30]})],
#                                                                 window_length=None)]).
#
#   ret = [fun(x, meta=meta) for x in iter]
# /Users/galkampel/Desktop/Projects/m5_forecasting/.venv/lib/python3.12/site-packages/sktime/utils/parallel.py:107: FitFailedWarning:
#                 In evaluate, fitting of forecaster ForecastingPipeline failed,
#                 you can set error_score='raise' in evaluate to see
#                 the exception message.
#                 Fit failed for the 12-th data split, on training data y_train with
#                 cutoff <NA>, and len(y_train)=685610.
#                 The score will be set to nan.
#                 Failed forecaster with parameters: ForecastingPipeline(steps=[ColumnEnsembleTransformer(feature_names_out='original',
#                                                      remainder='passthrough',
#                                                      transformers=[('ohe_week',
#                                                                     TabularToSeriesAdaptor(input_type='pandas',
#                                                                                            transformer=OHEwithBaseline(baseline_category='Monday', drop_first=True)),
#                                                                     ['weekday']),
#                                                                    ('ohe_month',
#                                                                     TabularToSeriesAdaptor(input_type='pandas',
#                                                                                            transformer=OHEwithBaseline(basel...
#                                                                                            transformer=OHEwithBaseline(baseline_category=2012, drop_first=True)),
#                                                                     ['year']),
#                                                                    ('ohe_event',
#                                                                     TabularToSeriesAdaptor(input_type='pandas',
#                                                                                            transformer=OHEwithBaseline(baseline_category='No Event', drop_first=True)),
#                                                                     ['event_name'])]),
#                            RecursiveTabularRegressionForecaster(estimator=LinearRegression(),
#                                                                 pooling='global',
#                                                                 transformers=[WindowSummarizer(lag_feature={'lag': [1,
#                                                                                                                     7,
#                                                                                                                     30]})],
#                                                                 window_length=None)]).
#
#   ret = [fun(x, meta=meta) for x in iter]
#     test_MeanAbsoluteError  test_MeanSquaredError   fit_time  pred_time  \
# 0                      NaN                    NaN  16.126457        NaN
# 1                 0.294911               0.420171  16.331428  84.461315
# 2                 0.322364               0.440255  15.110720  81.832642
# 3                 0.329753               0.452208  15.357371  81.645739
# 4                 0.334839               0.462853  15.337744  86.941025
# 5                 0.352274               0.477101  15.919943  86.585081
# 6                 0.348770               0.467569  16.739740  86.211847
# 7                 0.350692               0.473751  16.997711  85.973401
# 8                 0.350414               0.471303  16.895888  84.512696
# 9                 0.381319               0.531187  17.069292  87.027334
# 10                0.385442               0.533258  16.924980  83.341314
# 11                0.368664               0.511288  16.892499  84.889954
# 12                     NaN                    NaN  17.175527        NaN
# 13                0.516775               0.676648  17.133520  87.074426
# 14                0.523180               0.674481  17.507597  88.201618
# 15                0.535070               0.687863  19.250901  84.865166
# 16                0.540351               0.692484  18.603357  85.283885
# 17                0.537090               0.686387  18.212818  83.678150
# 18                0.533201               0.685966  18.645022  84.130975
# 19                0.552587               0.708036  18.785358  84.379038
# 20                0.572171               0.732212  18.420705  84.054894
# 21                0.573516               0.726559  18.733346  84.751498
# 22                0.568491               0.724600  19.245515  87.100753
# 23                0.561656               0.715024  19.417462  84.889518
#
#     len_train_window               cutoff
# 0                730                  NaN
# 1                760  2014-01-29 00:00:00
# 2                790  2014-02-28 00:00:00
# 3                820  2014-03-30 00:00:00
# 4                850  2014-04-29 00:00:00
# 5                880  2014-05-29 00:00:00
# 6                910  2014-06-28 00:00:00
# 7                940  2014-07-28 00:00:00
# 8                970  2014-08-27 00:00:00
# 9               1000  2014-09-26 00:00:00
# 10              1030  2014-10-26 00:00:00
# 11              1060  2014-11-25 00:00:00
# 12              1090                  NaN
# 13              1120  2015-01-24 00:00:00
# 14              1150  2015-02-23 00:00:00
# 15              1180  2015-03-25 00:00:00
# 16              1210  2015-04-24 00:00:00
# 17              1240  2015-05-24 00:00:00
# 18              1270  2015-06-23 00:00:00
# 19              1300  2015-07-23 00:00:00
# 20              1330  2015-08-22 00:00:00
# 21              1360  2015-09-21 00:00:00
# 22              1390  2015-10-21 00:00:00
# 23              1420  2015-11-20 00:00:00

# %%
lr_pipe.fit(y=y_train, X=X_train, fh=np.arange(1, 32))
# Out:
# ForecastingPipeline(steps=[ColumnEnsembleTransformer(feature_names_out='original',
#                                                      remainder='passthrough',
#                                                      transformers=[('ohe_week',
#                                                                     TabularToSeriesAdaptor(input_type='pandas',
#                                                                                            transformer=OHEwithBaseline(baseline_category='Monday', drop_first=True)),
#                                                                     ['weekday']),
#                                                                    ('ohe_month',
#                                                                     TabularToSeriesAdaptor(input_type='pandas',
#                                                                                            transformer=OHEwithBaseline(basel...gory=1, drop_first=True)),
#                                                                     ['month']),
#                                                                    ('ohe_event',
#                                                                     TabularToSeriesAdaptor(input_type='pandas',
#                                                                                            transformer=OHEwithBaseline(baseline_category='No Event', drop_first=True)),
#                                                                     ['event_name'])]),
#                            RecursiveTabularRegressionForecaster(estimator=LinearRegression(),
#                                                                 pooling='global',
#                                                                 transformers=[WindowSummarizer(lag_feature={'lag': [1,
#                                                                                                                     7,
#                                                                                                                     30]})],
#                                                                 window_length=None)])

# %%
y_pred_lr = lr_pipe.predict(X=X_test)

# %%
y_pred_lr
# Out:
#                                              sales
# state_id store_id item_id     date
# CA       CA_1     FOODS_3_003 2016-01-01  0.236185
#                               2016-01-02  0.320729
#                               2016-01-03  0.339611
#                               2016-01-04  0.294550
#                               2016-01-05  0.278473
# ...                                            ...
# WI       WI_3     FOODS_3_815 2016-01-27  0.299114
#                               2016-01-28  0.294344
#                               2016-01-29  0.461246
#                               2016-01-30  0.375521
#                               2016-01-31  0.384178
#
# [19499 rows x 1 columns]

# %%
y_test.query("sales > 0")
# Out:
#                                           sales
# state_id store_id item_id     date
# CA       CA_1     FOODS_3_006 2016-01-01      1
#                               2016-01-04      1
#                               2016-01-05      1
#                               2016-01-07      1
#                               2016-01-09      1
# ...                                         ...
# WI       WI_3     FOODS_3_806 2016-01-30      1
#                               2016-01-31      2
#                   FOODS_3_815 2016-01-02      1
#                               2016-01-19      2
#                               2016-01-24      1
#
# [5272 rows x 1 columns]

# %%
nc_results = evaluate(nc_model, cv=cv, y=y_train, scoring=scoring, return_model=False)
nc_results
# Out:
#     test_MeanAbsoluteError  test_MeanSquaredError  fit_time  pred_time  \
# 0                 0.216534               0.364233  1.726030   2.814924
# 1                 0.245787               0.438806  1.609134   2.959411
# 2                 0.300901               0.474349  1.658306   2.858850
# 3                 0.347483               0.534298  1.643998   2.943306
# 4                 0.269422               0.477238  1.666138   2.861238
# 5                 0.295972               0.508668  1.782051   2.847689
# 6                 0.327292               0.523931  1.697353   2.966795
# 7                 0.309009               0.513045  1.725646   2.860559
# 8                 0.311394               0.518211  1.730751   2.960388
# 9                 0.346741               0.589921  1.755859   2.873068
# 10                0.418230               0.644047  1.769870   2.875420
# 11                0.344674               0.581244  1.748654   2.970719
# 12                0.289507               0.605549  2.081323   2.960806
# 13                0.527504               0.813199  1.946898   2.992965
# 14                0.503445               0.800284  1.855836   2.929871
# 15                0.500106               0.790986  1.886134   2.925986
# 16                0.508744               0.805467  1.882993   3.047938
# 17                0.506041               0.788414  1.900664   2.942354
# 18                0.500795               0.783858  2.009079   2.959052
# 19                0.504134               0.789065  1.936575   3.060728
# 20                0.599152               0.880418  1.951146   2.961825
# 21                0.553948               0.842572  2.148089   2.992195
# 22                0.567303               0.866922  1.986253   3.113282
# 23                0.556704               0.841115  2.037013   2.973248
#
#     len_train_window               cutoff
# 0                730  2013-12-30 00:00:00
# 1                760  2014-01-29 00:00:00
# 2                790  2014-02-28 00:00:00
# 3                820  2014-03-30 00:00:00
# 4                850  2014-04-29 00:00:00
# 5                880  2014-05-29 00:00:00
# 6                910  2014-06-28 00:00:00
# 7                940  2014-07-28 00:00:00
# 8                970  2014-08-27 00:00:00
# 9               1000  2014-09-26 00:00:00
# 10              1030  2014-10-26 00:00:00
# 11              1060  2014-11-25 00:00:00
# 12              1090  2014-12-25 00:00:00
# 13              1120  2015-01-24 00:00:00
# 14              1150  2015-02-23 00:00:00
# 15              1180  2015-03-25 00:00:00
# 16              1210  2015-04-24 00:00:00
# 17              1240  2015-05-24 00:00:00
# 18              1270  2015-06-23 00:00:00
# 19              1300  2015-07-23 00:00:00
# 20              1330  2015-08-22 00:00:00
# 21              1360  2015-09-21 00:00:00
# 22              1390  2015-10-21 00:00:00
# 23              1420  2015-11-20 00:00:00

# %%
nc_model.fit(y_train, fh=np.arange(1, 32))
nc_preds = nc_model.predict()

# %%
ns_results = evaluate(ns_model, cv=cv, y=y_train, scoring=scoring, return_model=False)
ns_results
# Out:
#     test_MeanAbsoluteError  test_MeanSquaredError  fit_time  pred_time  \
# 0                 0.195866               0.370393  1.627568   5.800056
# 1                 0.264706               0.475558  1.633696   5.774674
# 2                 0.294807               0.499208  1.757581   5.775493
# 3                 0.312189               0.542305  1.646649   5.885356
# 4                 0.294118               0.520371  1.674034   5.761344
# 5                 0.319237               0.553146  1.799370   5.723478
# 6                 0.323476               0.560884  1.784916   5.811810
# 7                 0.306836               0.538225  1.721376   5.764027
# 8                 0.315845               0.556681  1.742194   5.859814
# 9                 0.342819               0.611333  1.743536   5.745822
# 10                0.383731               0.666809  1.852834   5.856131
# 11                0.366190               0.638736  1.792168   6.215275
# 12                0.388712               0.696470  1.802654   5.809648
# 13                0.473927               0.816343  1.961453   5.835064
# 14                0.493694               0.838659  1.832616   5.970002
# 15                0.513514               0.856038  1.857229   5.872426
# 16                0.525066               0.868142  1.964080   5.940736
# 17                0.506995               0.839570  1.894517   5.893197
# 18                0.518442               0.853887  1.897553   5.871132
# 19                0.539269               0.870348  1.931212   6.008101
# 20                0.575358               0.917828  1.928365   5.906410
# 21                0.578590               0.926641  2.053931   5.915322
# 22                0.562851               0.913297  1.976784   5.931451
# 23                0.556227               0.892454  2.035253   5.930371
#
#     len_train_window               cutoff
# 0                730  2013-12-30 00:00:00
# 1                760  2014-01-29 00:00:00
# 2                790  2014-02-28 00:00:00
# 3                820  2014-03-30 00:00:00
# 4                850  2014-04-29 00:00:00
# 5                880  2014-05-29 00:00:00
# 6                910  2014-06-28 00:00:00
# 7                940  2014-07-28 00:00:00
# 8                970  2014-08-27 00:00:00
# 9               1000  2014-09-26 00:00:00
# 10              1030  2014-10-26 00:00:00
# 11              1060  2014-11-25 00:00:00
# 12              1090  2014-12-25 00:00:00
# 13              1120  2015-01-24 00:00:00
# 14              1150  2015-02-23 00:00:00
# 15              1180  2015-03-25 00:00:00
# 16              1210  2015-04-24 00:00:00
# 17              1240  2015-05-24 00:00:00
# 18              1270  2015-06-23 00:00:00
# 19              1300  2015-07-23 00:00:00
# 20              1330  2015-08-22 00:00:00
# 21              1360  2015-09-21 00:00:00
# 22              1390  2015-10-21 00:00:00
# 23              1420  2015-11-20 00:00:00

# %%
ns_model.fit(y_train, fh=np.arange(1, 32))
ns_preds = ns_model.predict()

# %%
def plot_preds(y_train, y_test, preds_dict, state_id, store_id, item_id, **kwargs_plot):
    y = pd.concat([y_train.loc[state_id, store_id, item_id], y_test.loc[state_id, store_id, item_id]], axis=0)
    fig, ax = plt.subplots(figsize=(12, 6))
    ax.plot(y, label="train", alpha=kwargs_plot.get("alpha", 0.7))
    for label, (preds, pred_color) in preds_dict.items():
        y_pred = preds.loc[state_id, store_id, item_id]
        ax.plot(y_pred, label=label, color=pred_color, alpha=kwargs_plot.get("alpha", 0.7))
    ax.set_title(f"{store_id} {item_id}")    
    ax.legend()
    fig.autofmt_xdate()
    plt.show()


def residual_plot(y_test, preds_dict, state_id, store_id, item_id, **kwargs_plot):
    fig, axes = plt.subplots(figsize=(6, 8), nrows=len(pred_dict), sharex=True,layout="tight")
    for i, (pred_name, (preds, _)) in enumerate(preds_dict.items()): 
        residuals = y_test.loc[state_id, store_id, item_id] - preds.loc[state_id, store_id, item_id]
        axes[i].plot(residuals, color="salmon")
        axes[i].set_title(f"Residual Plot {store_id} {item_id} ({pred_name})")
    fig.autofmt_xdate()
    fig.suptitle("Residual Plot")
    plt.show()

# %%
pred_dict = {"LR": [y_pred_lr, "orange"], "Naive": [nc_preds, "blueviolet"], "Naive Seasonal": [ns_preds, "goldenrod"]}

# %%
plot_preds(y_train, y_test, pred_dict, state_id="CA", store_id="CA_1", item_id="FOODS_3_006")

# %%
residual_plot(y_test, pred_dict, state_id="CA", store_id="CA_1", item_id="FOODS_3_006")

# %%
import numpy as np
from sklearn.ensemble import HistGradientBoostingRegressor

rng = np.random.default_rng(seed=0)

# %%
X = rng.random((10_000, 4))
y = rng.choice([0, 1, 2], size=10_000, replace=True, p=[0.8, 0.1, 0.1])
model = HistGradientBoostingRegressor().fit(X, y)
preds = model.predict(X)
assert y.min() == 0
assert preds.min() < 0

# %%
pd.Series(preds).min()
# Out:
# np.float64(-0.12116609094628825)
